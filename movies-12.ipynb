# %%
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Downloads/movies.csv")

# %%
data.describe()
# Out:
#                srno          year        rating          time
# count  49590.000000  49590.000000  10814.000000  45836.000000
# mean   24795.500000   2002.303428      3.451248   2628.445436
# std    14315.544261     12.534555      0.495601   1604.646265
# min        1.000000   1913.000000      1.400000     52.000000
# 25%    12398.250000   1999.000000      3.100000   1356.000000
# 50%    24795.500000   2007.000000      3.500000   2563.000000
# 75%    37192.750000   2010.000000      3.800000   2877.000000
# max    49590.000000   2014.000000      4.500000  28813.000000

# %%
data.head(5)
# Out:
#    srno                 movie  year  rating    time
# 0     1  The Nightmare Before  1993     3.9  4568.0
# 1     2             The Mummy  1932     3.5  4388.0
# 2     3  Orphans of the Storm  1921     3.2  9062.0
# 3     4  The Object of Beauty  1991     2.8  6150.0
# 4     5            Night Tide  1963     2.8  5126.0

# %%
data1=data.loc[(data.time>5000)]
data1
# Out:
#         srno                                  movie  year  rating    time
# 2          3                   Orphans of the Storm  1921     3.2  9062.0
# 3          4                   The Object of Beauty  1991     2.8  6150.0
# 4          5                             Night Tide  1963     2.8  5126.0
# 5          6                    One Magic Christmas  1985     3.8  5333.0
# 6          7                       Muriel's Wedding  1994     3.5  6323.0
# ...      ...                                    ...   ...     ...     ...
# 49564  49565                        American Addict  2013     3.5  5377.0
# 49579  49580  Underground: The Julian Assange Story  2012     3.7  5665.0
# 49583  49584                           Sunset Strip  2012     3.0  5770.0
# 49584  49585                           Silver Bells  2013     3.5  5287.0
# 49586  49587    Top Gear: Series 19: Africa Special  2013     NaN  6822.0
#
# [5897 rows x 5 columns]

# %%
data.head(50)
# Out:
#     srno                                          movie  year  rating     time
# 0      1                           The Nightmare Before  1993     3.9   4568.0
# 1      2                                      The Mummy  1932     3.5   4388.0
# 2      3                           Orphans of the Storm  1921     3.2   9062.0
# 3      4                           The Object of Beauty  1991     2.8   6150.0
# 4      5                                     Night Tide  1963     2.8   5126.0
# 5      6                            One Magic Christmas  1985     3.8   5333.0
# 6      7                               Muriel's Wedding  1994     3.5   6323.0
# 7      8                                  Mother's Boys  1994     3.4   5733.0
# 8      9                    Nosferatu: Original Version  1929     3.5   5651.0
# 9     10                                   Nick of Time  1995     3.4   5333.0
# 10    11                                Broken Blossoms  1919     3.3   5367.0
# ...

# %%
data.head(100)
# Out:
#     srno                           movie  year  rating    time
# 0      1            The Nightmare Before  1993     3.9  4568.0
# 1      2                       The Mummy  1932     3.5  4388.0
# 2      3            Orphans of the Storm  1921     3.2  9062.0
# 3      4            The Object of Beauty  1991     2.8  6150.0
# 4      5                      Night Tide  1963     2.8  5126.0
# ..   ...                             ...   ...     ...     ...
# 95    96                      The Hunted  1995     3.4  6605.0
# 96    97          The Great Waldo Pepper  1975     3.5  6467.0
# 97    98  Godzilla: King of the Monsters  1956     3.5  4828.0
# 98    99  Highlander 2: Renegade Version  1991     3.1  6585.0
# 99   100                       High Noon  1952     3.9  5087.0
#
# [100 rows x 5 columns]

# %%
data.tail(50)
# Out:
#         srno                                              movie  year  rating  \
# 49540  49541  Life With Boys: Season 1: This Time the Proble...  2011     NaN
# 49541  49542  Life With Boys: Season 1: In the Principal's O...  2011     NaN
# 49542  49543                                 El Fuente: 5994 MP  2013     3.5
# 49543  49544    Life With Boys: Season 1: Monkey Talk with Boys  2011     NaN
# 49544  49545                                   El Fuente: 50 MP  2013     3.3
# 49545  49546                                  Bo Burnham: what.  2013     4.1
# 49546  49547  Life With Boys: Season 1: A Perfect Life with ...  2011     NaN
# 49547  49548      Life With Boys: Season 1: Wrestling with Boys  2011     NaN
# 49548  49549                           Life With Boys: Season 1  2011     4.1
# 49549  49550                                   El Fuente: 30 MP  2013     3.3
# 49550  49551                                 El Fuente: 2997 MP  2013     3.2
# ...

# %%
data3=data.loc[(data.rating>=3)&(data.year>2000)&(data.year<=2010)]
data3
# Out:
#         srno                                              movie  year  rating  \
# 438      439                                         Monkeybone  2001     3.1
# 507      508                                           Impostor  2001     3.4
# 514      515                                           Hannibal  2001     3.6
# 523      524                                           Blow Dry  2001     3.3
# 541      542                                Along Came a Spider  2001     3.7
# ...      ...                                                ...   ...     ...
# 49320  49321                        Dave Gorman Stand-Up. Live.  2010     3.4
# 49333  49334  Frank Skinner Stand-Up: Live from Birmingham's...  2008     3.0
# 49334  49335                         Signing Time: Collection 1  2007     3.8
# 49394  49395                                             A Liga  2010     3.8
# 49580  49581            Curious George: A Very Monkey Christmas  2009     3.8
#
#          time
# 438    5561.0
# ...

# %%
datat=data.sort_values('time')
datat
# Out:
#         srno                              movie  year  rating  time
# 40150  40151                      Trailer: Pain  2012     3.6  52.0
# 41081  41082               Trailer: Get to Work  2012     3.3  55.0
# 41082  41083             Trailer: Give and Take  2012     3.3  66.0
# 43166  43167                   Trailer: Emperor  2013     3.1  67.0
# 43330  43331               Trailer: Blood Angel  2013     4.2  69.0
# ...      ...                                ...   ...     ...   ...
# 49556  49557                       Shinobi Girl  2012     2.0   NaN
# 49561  49562  My Hope America with Billy Graham  2013     3.9   NaN
# 49565  49566  My Hope America with Billy Graham  2013     3.9   NaN
# 49588  49589                    Kate Plus Ei8ht  2010     2.7   NaN
# 49589  49590          Kate Plus Ei8ht: Season 1  2010     2.7   NaN
#
# [49590 rows x 5 columns]

# %%
datat=data.sort_values('rating')
datat
# Out:
#         srno                                              movie  year  rating  \
# 40934  40935                                             Lagegi  2007     1.4
# 42115  42116                                Sun Yaar Chill Maar  2007     1.4
# 40826  40827                                             Lagegi  2007     1.4
# 42160  42161                                Sun Yaar Chill Maar  2007     1.4
# 41396  41397                           Meri Toh Lag Gayi Naukri  2011     1.5
# ...      ...                                                ...   ...     ...
# 49563  49564    My Hope America with Billy Graham: Lose to Gain  2013     NaN
# 49576  49577  Barbie: Life in the Dreamhouse: Barbie Life in...  2013     NaN
# 49577  49578  Barbie: Life in the Dreamhouse: Barbie Life in...  2013     NaN
# 49586  49587                Top Gear: Series 19: Africa Special  2013     NaN
# 49587  49588  Fireplace For Your Home: Crackling Fireplace w...  2010     NaN
#
#          time
# 40934     NaN
# ...

# %%
import pymysql

# %%
x=pymysql.connect(host='localhost',user='root',password='Passwor@123',database='project2')
cr=x.cursor()

# %%
cr.execute('create table soldier23(name char(50),age int(5))')
cr.execute('insert into soldier23(name,age)values("vikram",45)')
cr.execute('insert into soldier23(name,age)values("ram",35)')
# Out:
# 1

# %%
x.commit()
x.close()

# %%
cr.execute('insert into data1(id,name,mob,dept) values(110,"jerome",00000,99)')
# Out:
# 1

# %%
cr.execute('create table soldier(id int(5),name char(20),age int(10))')
cr.execute('insert into soldier (id,name,age) values(1,"vikram",45)')
cr.execute('insert into soldier (id,name,age) values(2,"ram",35)')
cr.execute('insert into soldier (id,name,age) values(3,"ravi",30)')

# %%
x.commit()
x.close()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 x.commit()
#       2 x.close()
#
# File ~/Anaconda/lib/python3.10/site-packages/pymysql/connections.py:471, in Connection.commit(self)
#     464 def commit(self):
#     465     """
#     466     Commit changes to stable storage.
#     467
#     468     See `Connection.commit() <https://www.python.org/dev/peps/pep-0249/#commit>`_
#     469     in the specification.
#     470     """
# --> 471     self._execute_command(COMMAND.COM_QUERY, "COMMIT")
#     472     self._read_ok_packet()
#
# File ~/Anaconda/lib/python3.10/site-packages/pymysql/connections.py:797, in Connection._execute_command(self, command, sql)
#     792 """
#     793 :raise InterfaceError: If the connection is closed.
#     794 :raise ValueError: If no username was specified.
#     795 """
#     796 if not self._sock:
# ...
